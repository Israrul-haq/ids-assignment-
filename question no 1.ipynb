# %%
#install scikitplot
# !pip install scikit-plot

# %%
#import libraries
from sklearn import preprocessing
import pandas as pd
import math

#import different ML classifiers
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
from sklearn.svm import SVC, LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

#import ML evaluation metrics
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn import metrics, model_selection

#import scikitplot to plot confusion matrix
import scikitplot as skplt

# %%
#read CSV (dataset) file
df_gender = pd.read_csv('/content/drive/MyDrive/gender-prediction.csv')
df_gender
# Out:
#     height  weight beard hair_length  shoe_size scarf eye_color  gender
# 0       71     176   yes       short         44    no     black    male
# 1       68     165    no        bald         41    no     black    male
# 2       62     132    no      medium         37   yes      blue  female
# 3       65     138    no        long         38    no      gray  female
# 4       70     197   yes      medium         43    no      gray    male
# ..     ...     ...   ...         ...        ...   ...       ...     ...
# 75      65      99    no       short         39   yes     green  female
# 76      61      98    no       short         37    no     brown  female
# 77      67     119   yes       short         40    no     black    male
# 78      70     190   yes      medium         43    no      gray    male
# 79      62     142   yes        long         37    no      blue  female
#
# [80 rows x 8 columns]

# %%
print("Number of lines present:-") 
len(df_gender)

# %%
total_cols=len(df_gender.axes[1])
print("Number of attributes: "+str(total_cols))

# %%
#converting strings into numbers
labels = preprocessing.LabelEncoder()
p_encoded = labels.fit_transform(	df_gender['gender'])
max_cod=p_encoded.max()
type_of_instences=max_cod + 1
print ("no of posible attribute velues")
print(type_of_instences)

# %%
catagorical_attribute=df_gender.select_dtypes(include=['object']).columns.to_list()
print("no of catagorical attributes are ")
print(len(catagorical_attribute))

# %%
a=df_gender.gender.value_counts()
total_genders=df_gender.gender.size
males=a.male
females=a.female
percentage_of_males=(males/total_genders)*100
percentage_of_females=100-percentage_of_males
print("ratio of male vs female" , math.floor(percentage_of_males) , ":" , math.ceil(percentage_of_females))
